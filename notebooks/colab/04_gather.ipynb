# %% [markdown]
# # DartLab -- Gather
#
# [![Open in Colab](https://img.shields.io/badge/Open_in_Colab-Google-ea4647?style=for-the-badge&labelColor=050811&logo=googlecolab&logoColor=white)](https://colab.research.google.com/github/eddmpython/dartlab/blob/master/notebooks/colab/04_gather.ipynb)
# [![Open in Molab](https://img.shields.io/badge/Open_in_Molab-marimo-38bdf8?style=for-the-badge&labelColor=050811)](https://molab.marimo.io/github/eddmpython/dartlab/blob/master/notebooks/marimo/04_gather.py)
#
# `gather()` -- one function for all external market data.
# Price, flow, macro, news -- all as Polars DataFrames.

# %%
# !pip install -q dartlab

# %%
import dartlab

# %% [markdown]
# ## Guide -- all axes

# %%
dartlab.gather()

# %% [markdown]
# ## Price

# %%
# KR stock -- 1-year OHLCV
dartlab.gather("price", "005930")

# %%
# custom date range
dartlab.gather("price", "005930", start="2020-01-01")

# %%
# US stock
dartlab.gather("price", "AAPL", market="US")

# %% [markdown]
# ## Flow

# %%
# supply/demand flow (KR only)
dartlab.gather("flow", "005930")

# %% [markdown]
# ## Macro

# %%
# KR macro indicators (12 key series)
dartlab.gather("macro")

# %%
# US macro indicators (25 key series)
dartlab.gather("macro", market="US")

# %%
# single indicator
dartlab.gather("macro", "CPI")

# %%
dartlab.gather("macro", "FEDFUNDS")

# %% [markdown]
# ## News

# %%
dartlab.gather("news", "삼성전자")

# %% [markdown]
# ## Company bound

# %%
c = dartlab.Company("005930")
c.gather("price")
