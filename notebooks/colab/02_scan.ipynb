# %% [markdown]
# # DartLab -- Scan
#
# [![Open in Colab](https://img.shields.io/badge/Open_in_Colab-Google-ea4647?style=for-the-badge&labelColor=050811&logo=googlecolab&logoColor=white)](https://colab.research.google.com/github/eddmpython/dartlab/blob/master/notebooks/colab/02_scan.ipynb)
# [![Open in Molab](https://img.shields.io/badge/Open_in_Molab-marimo-38bdf8?style=for-the-badge&labelColor=050811)](https://molab.marimo.io/github/eddmpython/dartlab/blob/master/notebooks/marimo/02_scan.py)

# %%
# !pip install -q dartlab

# %%
import dartlab

# %%
dartlab.search("삼성전자")

# %%
dartlab.listing()

# %%
dartlab.scan("ratio")

# %%
dartlab.scan("ratio", "roe")

# %%
dartlab.scan("account", "매출액")

# %% [markdown]
# ## Unified Scan Interface
#
# 11-axis cross-market analysis via .

# %%
# guide -- all axes + usage
dartlab.scan()

# %%
# governance scan -- full market
dartlab.scan("governance")

# %%
# cashflow pattern classification
dartlab.scan("cashflow")

# %%
# audit risk flags
dartlab.scan("audit")

# %%
# insider ownership changes
dartlab.scan("insider")
