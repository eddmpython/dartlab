# %%
# !pip install -q dartlab

# %%
import dartlab

# provider 설정: dartlab setup oauth-codex / gemini / groq / openai / ollama
dartlab.setup()

# %%
# streams to stdout, returns full text
answer = dartlab.ask("삼성전자 재무건전성 분석해줘")
